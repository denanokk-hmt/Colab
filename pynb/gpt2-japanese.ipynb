# %% [markdown]
# # [gpt2-japanese の mediumモデル による日本語テキスト生成](https://note.com/npaka/n/n50cec2c7150e)

# %% [markdown]
# ## [gpt2-japanese](https://github.com/tanreinama/gpt2-japanese) のインストール

# %%
# gpt2-japaneseのインストール
# !git clone https://github.com/tanreinama/gpt2-japanese
# %cd gpt2-japanese
# !pip uninstall tensorflow -y
# !pip install -r requirements.txt
# Out:
# Cloning into 'gpt2-japanese'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 114 (delta 30), reused 65 (delta 24), pack-reused 41
# Receiving objects: 100% (114/114), 1.19 MiB | 22.95 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# /content/gpt2-japanese
# Uninstalling tensorflow-2.3.0:
#   Successfully uninstalled tensorflow-2.3.0
# ...
#      |████████████████████████████████| 411.0MB 41kB/s
# ...
#      |████████████████████████████████| 512kB 46.8MB/s
# ...
#      |████████████████████████████████| 3.8MB 51.3MB/s
# ...
#      |████████████████████████████████| 51kB 7.0MB/s
# ...
#   Created wheel for jaconv: filename=jaconv-0.2.4-cp36-none-any.whl size=12284 sha256=121d696f838459aaa7d29ab46990d58722db0de8a954440f4d6cd85144744752
#   Stored in directory: /root/.cache/pip/wheels/e1/46/f7/85a7f89bd3263423c8530dfed16083f9a142cc0fc78c81ff32
# ...

# %% [markdown]
# ## mediumモデルのダウンロード

# %%
# mediumモデルのダウンロード
# !wget https://www.nama.ne.jp/models/gpt2ja-medium.tar.bz2
# !tar xvfj gpt2ja-medium.tar.bz2
# Out:
# --2020-11-11 01:28:47--  https://www.nama.ne.jp/models/gpt2ja-medium.tar.bz2
# Resolving www.nama.ne.jp (www.nama.ne.jp)... 112.78.112.176
# Connecting to www.nama.ne.jp (www.nama.ne.jp)|112.78.112.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1231913634 (1.1G) [application/x-bzip2]
# Saving to: ‘gpt2ja-medium.tar.bz2’
#
# gpt2ja-medium.tar.b  97%[==================> ]   1.11G  4.07MB/s    in 5m 1s
#
# 2020-11-11 01:33:49 (3.80 MB/s) - Connection closed at byte 1197244330. Retrying.
#
# --2020-11-11 01:33:50--  (try: 2)  https://www.nama.ne.jp/models/gpt2ja-medium.tar.bz2
# Connecting to www.nama.ne.jp (www.nama.ne.jp)|112.78.112.176|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 1231913634 (1.1G), 34669304 (33M) remaining [application/x-bzip2]
# Saving to: ‘gpt2ja-medium.tar.bz2’
#
# gpt2ja-medium.tar.b 100%[+++++++++++++++++++>]   1.15G  3.03MB/s    in 13s
#
# ...

# %% [markdown]
# 「gpt2-generate.py」のパラメータは、次のとおりです。
#
# * --model : モデル (gpt2ja-medium)
# * --num_generate : 生成するテキスト数 (デフォルト5)
# * --context : 開始テキスト (デフォルト <|endoftext|>)
# * --top_k : 各ステップでk個の単語からランダム選択 (デフォルト40)
# * --top_p : 生成テキストを累積確率に制限 (デフォルト0、制限なし)
# * --temperature : 温度（デフォルト1、推奨0.7〜1.0）

# %% [markdown]
# ## ランダムな日本語テキストの生成

# %%
# ランダムな日本語テキストの生成
# !python gpt2-generate.py --model gpt2ja-medium --num_generate 1
# Out:
# WARNING:tensorflow:From /content/gpt2-japanese/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From gpt2-generate.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From gpt2-generate.py:92: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-11-11 01:35:57.263803: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-11-11 01:35:57.268444: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-11-11 01:35:57.268626: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2591640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# ## 開始テキストに続く日本語テキストの生成

# %%
# !python gpt2-generate.py --model gpt2ja-medium --context="むかし、むかし、あるところに、おじいさんとおばあさんがいました。おじいさんは山へ刈かりに、おばあさんは川へ洗濯に行きました。"
# Out:
# WARNING:tensorflow:From /content/gpt2-japanese/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From gpt2-generate.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From gpt2-generate.py:92: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-11-11 01:40:28.416484: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-11-11 01:40:28.420814: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-11-11 01:40:28.421001: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x25ad640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# ### 開始テキストに続く日本語テキストの生成

# %%
# !python gpt2-generate.py --model gpt2ja-medium --context="こんにちは、コーディネートについてお尋ねです♡一昨年、水色のコートを買ったのですが、まだ着れていなくて、合わせ方を教えて欲しいです"

### 以下の文章例が自動生成される。
"""
(^_^)今年は、ブラウンのロングコートは買いました。今年も気になった、トップス等を着てみました。
ブラックだと、着れるのが見つからず 笑。色んなブランドのコートが、欲しいので、このトップスをオーダーしました。
ワンピース、デニム、ショートパンツ等で、ゆったりした着こなしが作れるので、今は ワンピース派。その中に、ニットと合わせる予定です。 
白のトップスから、インナーにインナーが選べる、と聞いて、白やグレーのインナーを着ようかな?なんて考えてます。
トップスも、このニットにインすれば、シンプルなニットに、簡単に着れますよね?ワンピースやコートから、お出かけの時、お出かけコーデに、なるのかもしれません。
ニットの色は・・・・やっぱりブラックが欲しい。白でも、インナーに着れますねー。
そして、このネックレスの存在です!この、白のブレスレットに!ニットソーニット、ニット、ジャケットのコーディネートに合わせたいと思います⑅◡̈*
サイドのアクセントもかわいいですよねー、白コーデに合わせたいので、シルバーに白のリングをいれて、アクセントにしてみます♪
    画像お借りしました✧*。お出かけの時はブラウンのコ
========
❤︎コートは、So-netのプチプラアウターを愛用しています✧︎⑅tops:GUTObag:ZARAmoad:GUバッグは、LavishGateのプチプラのショルダーバッグ↓↓↓    ブラックのショルダーバッグ Mサイズ  ↓↓↓           ニットカーディガン (Mサイズ×2)         ニットカーディガン(ブラック)                   トップス:KBFL                                                                                      バッグ:So.KOBE                                                       ニットソーイパンツ:KBFLバッグ:B.C STOREパンプス:アウトレットシューズ:meriスニーカー:converse【ポイント10倍】送料無料【正規品】ファーリー パンプス パイソン フラットソール フラット パンプス パイソン柄 フラットシューズ ぺたんこ ローヒール ブラック パイソン フラ
========
⑅◡̈*ホワイトのコートも合いますが、私のは、グレーのコートにグレーのパンプスなので、ホワイトはどちらかと言えば、暖かですが、グレーのパンプスはとても暖かくて、とっても良く伸びてくれるので楽チン♡ホワイトコートを羽織ってる時は、少しゆったりめのコーデアイテムに、白コートを羽織っても良かったなーと思うことが多いですが、そのままでは、私には合わないっぽいです♡♡白コートは、着回しコーデにピッタリだと思いますが、私のようにコートを羽織った後、黒のパンプスを履いたり、ピンクのコートを羽織ったりすると、もう寒いのよね…と感じる方もいらっしゃるそうです♡白コートはもともとこだわりのパンプスの代わりとしてしか着ることはないので、どうなのかな…ちょっと気になりました◡̈こちらは、今夏に色違いのホワイトコートと黒のパンプスを合わせてみたいと思っているのですが、やっぱりグレーのほうが可愛いです◡̈ホワイトコートにグレーのパンプスを合わせると、大人っぽい印象になるので、こちらは気になります! スカートは白よりも、グレーのほうがしっかりとした素材で大人に見えそうでとても可愛い♡今日も、なんだか、暑い…と感じた
========
今日は、ニットとパンツの合わせです♪↓  画像お借りしました♡グレーのコートとグレーのパンツ↓  そして、去年はシアーな色のスカート♡↓↓↓  これは今年も履きたい↓↓  そして、グレーのスカートに合わせているのは↑↓  こんな感じです⑅◡̈*  シアーに見えるから、気に入ってます↓↓↓    グレーのシャツは、今年も、色違いにして履くことにしましたグレーのスカートは、去年と同じ(笑)毎年、同じのに、着こなすコーデはこんな感じですごく、色が抜けやすいんですが、去年、去年と、シアー色のパンツと合わせるのはものすごく好きなので、今年も絶対履きたいです  そして、今年も可愛いニットとパンツの着回しです♡    昨年は、ニット↓  去年は、シャツ↓  この春も絶対着たい…⑅◡̈*  ちなみに、去年のこれ↓↓         シアーを、今年も着たいところです⑅◡̈*              シアーに見えるニットは去年も買ったのですが、今年は昨年のシアーの色が透けて見えるニットが今年も追加でこの春に買いました⑅◡̈*       可愛いシアーオーバード素材のニットが可愛いこちら↓       シ
========
❤︎ お洋服のことなら、たくさんあるのでご紹介させてください♡▼アクセサリーは、楽天のものを♡▼ニットワンピースやレースブラウスをカジュアルに♡ワンピースの中にもパンツをいれてカジュアルに⑅◡̈*シンプルコーデのポイントになるところ。前回ご紹介したワンピースはこちら♡コーティングのコートは、こちらのワンピースパケット♡この日は、こちらのシンプルコーデでした🐯︎⑅◡̈*バッグは昨年の夏にこちらを買ったもの♡ショルダーバッグとサンダル(こちら)の甘辛コーデだったので、今年はやっぱり甘辛いのです〜♡♡2色とも、ベージュ×グレージュ⁈で、合わせました⑅◡̈*ショルダーバッグは、⑅◡̈▷こちらのお店で購入※こちら♡▼バッグはこちらのショルダーバッグ⑅◡̈⑅◡̈⑅◡̈◡̈⑅◡̈(送料・代引き手数料込み) ▼シューズはこちらのサンダル⑅◡̈⑅◡̈⑅◡̈⑅◡̈◡̈⑅◡̈(価格は全て税別・送料無料)<DATE> 13:59まで限定価格・即納 ショルダーバッグ レディース【バッグ バッグ フェイクレザー 本革 レザー レザー風バッグ かばん かばん お財布 トートバッグ】【あす楽】▼コーデのベースになるの
"""
# Out:
# WARNING:tensorflow:From /content/gpt2-japanese/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From gpt2-generate.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From gpt2-generate.py:92: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-11-11 01:42:36.720624: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-11-11 01:42:36.725052: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-11-11 01:42:36.725237: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1abd640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# ## 文章ベクトル生成

# %%
# !python gpt2-transform.py --model gpt2ja-medium --context="江戸時代のインターネット回線"
# Out:
# WARNING:tensorflow:From /content/gpt2-japanese/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From gpt2-transform.py:53: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From gpt2-transform.py:57: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-11-11 01:38:40.727879: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-11-11 01:38:40.732589: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-11-11 01:38:40.732806: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x328d640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
