# %% [markdown]
# # 事前準備
#
# *   タイムアウト切れ回避対応
# *   永続化対応:GDrive接続
# *   共通パスの指定

# %%
#タイムアウト切れ回避対応
# %%javascript
function ClickConnect(){
console.log("Working");
document.querySelector("colab-toolbar-button#connect").click()
}setInterval(ClickConnect,60000)

# %% [markdown]
# **実行設定値**

# %%
#クライアントID, 実行日
clientId = "fdc"
execute_date= "20230501"

# %% [markdown]
# Gドライブフォルダパス

# %%
#デフォルトGドライブパスを指定
fldContentDrive = '/content/drive/'
fldContentDriveMyDrive = fldContentDrive + 'MyDrive/'

#Colab Notebooks
fldContentDriveMyDriveColabNotebooks = fldContentDriveMyDrive + 'ColabNotebooks/'
fldContentDriveMyDriveColabNotebooksData = fldContentDriveMyDriveColabNotebooks + 'data/'
fldContentDriveMyDriveColabNotebooksDataInput = fldContentDriveMyDriveColabNotebooksData + 'input/' + clientId + "_" + execute_date + '/' 
fldContentDriveMyDriveColabNotebooksDataOutput = fldContentDriveMyDriveColabNotebooksData + 'output/' + clientId + "_" + execute_date + '/'

# %% [markdown]
# Gドライブ接続

# %%
from google.colab import drive
drive.mount(fldContentDrive)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# **インプットファイル名を配列に指定**

# %%
#Gドライブのアウトプットフォルダからファイル名を調査
import glob
files = glob.glob(fldContentDriveMyDriveColabNotebooksDataOutput + "*")
for file in files:
    print(file)
# Out:
# /content/drive/MyDrive/ColabNotebooks/data/output/fdc_20230501/Untitled folder
# /content/drive/MyDrive/ColabNotebooks/data/output/fdc_20230501/inferenced_t5_t5_1-1000.csv
# /content/drive/MyDrive/ColabNotebooks/data/output/fdc_20230501/inferenced_t5_t5_1001-2000.csv

# %%
#インプットファイル名（配列）
file_names = [
    "inferenced_t5_t5_1-1000.csv",
    "inferenced_t5_t5_1001-2000.csv",
    ]

# %% [markdown]
# アウトプットフォルダを作成

# %%
import os

#インプットプットフォルダを作成する
#if not os.path.exists(fldContentDriveMyDriveColabNotebooksDataInput):
#  os.mkdir(fldContentDriveMyDriveColabNotebooksDataInput)

#アウトプットフォルダを作成する
if not os.path.exists(fldContentDriveMyDriveColabNotebooksDataOutput):
  os.mkdir(fldContentDriveMyDriveColabNotebooksDataOutput)

# %% [markdown]
# # 入力するソースを準備する
#
#
# *   **行単位のフォーマット(CSV)**：
#     <br>---------------------------------------------------------
#     <br>{行番号} , {固有ID} , {名称} , {解析する文章}   (カンマ区切り）
#     <br>行番号：　通し番号でよい
#     <br>固有ID：　商品IDなど
#     <br>名称:　商品名など→固有でなくてよい
#     <br>解析する文章:　商品説明の要約文など
#     <br>---------------------------------------------------------
#
#
# *   **※クライアントなどから連携されたデータをCSV化して、inputフォルダへ格納しておく**

# %%
#チェック
# %ls {fldContentDriveMyDriveColabNotebooksDataInput}
# Out:
# stop_words  t5_1001-2000.csv  t5_1-1000.csv

# %% [markdown]
# # ストップワード登録
#
#
# *   **行単位の単語**：
#     <br>---------------------------------------------------------
#     <br>{単語}
#     <br>---------------------------------------------------------
#
#
# *   **※先に調査し、不要なワードを格納しておく**
# *   ストップワードファイルの読み込みを配列化する

# %%
input_fld = fldContentDriveMyDriveColabNotebooksDataInput

stop_words_file_name = "stop_words"
input_file_path = input_fld + stop_words_file_name
stop_words_file = []

with open(input_file_path) as f:
  for index, line in enumerate(f):
    stop_words_file.append(line.replace('\n', ''))

print(stop_words_file)
# Out:
# ['使用', '詳細']

# %% [markdown]
# # 形態素解析ライブラリを準備
#
# GiNZAとspaCyをインストールして、
# 正常に動作するかを確認

# %%
# !pip install ginza==4.0.5 ja-ginza 
# !pip install sortedcontainers~=2.1.0
import pkg_resources, imp
imp.reload(pkg_resources)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ginza==4.0.5 in /usr/local/lib/python3.10/dist-packages (4.0.5)
# Requirement already satisfied: ja-ginza in /usr/local/lib/python3.10/dist-packages (4.0.0)
# Requirement already satisfied: spacy<3.0.0,>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from ginza==4.0.5) (2.3.9)
# Requirement already satisfied: SudachiPy>=0.4.9 in /usr/local/lib/python3.10/dist-packages (from ginza==4.0.5) (0.6.7)
# Requirement already satisfied: SudachiDict-core>=20200330 in /usr/local/lib/python3.10/dist-packages (from ginza==4.0.5) (20230110)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (3.0.8)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (7.4.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (0.7.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (0.10.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (1.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (1.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (4.65.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (67.7.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (1.22.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.5) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.5) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.5) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.5) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.5) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sortedcontainers~=2.1.0 in /usr/local/lib/python3.10/dist-packages (2.1.0)
# <module 'pkg_resources' from '/usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py'>

# %%
import spacy
import ginza
nlp = spacy.load("ja_ginza")
ginza.set_split_mode(nlp, "C")
doc = nlp("彼女はペンパイナッポーアッポーペンと恋ダンスを踊った。")

for tok in doc:
    print(
        tok.i,  # 親ドキュメント内のトークンのインデックス。
        tok.text,  # 逐語的なテキストコンテンツ

        # 逐語的なテキストコンテンツ（Token.textと同じ）
        # 主に他の属性との一貫性のために存在します。
        #tok.orth_,
        #tok.lemma_,  # 語尾変化のない接尾辞のない、トークンの基本形式
        
        tok.pos_,  # 品詞（英語の大文字）
        tok.tag_,  # きめの細かい品詞
        tok.head.i, # headはこのトークンの構文上の親、または「ガバナー」
        tok.dep_,  # 構文従属関係

        # トークンの基準、つまりトークンテキストの正規化された形式
        # 通常、言語のトークナイザー例外またはノルム例外で設定されます。
        tok.norm_,
        
        ## 名前付きエンティティタグのIOBコード
        ## 「B」はトークンがエンティティを開始することを意味し、「I」はそれがエンティティの内部にあることを意味し、
        ## 「O」はそれがエンティティの外部にあることを意味し、「」はエンティティタグが設定されていないことを意味します。
        #tok.ent_iob_,
        #tok.ent_type_,  # 名前付きエンティティタイプ
    )
# Out:
# 0 彼女 PRON 代名詞 7 nsubj 彼女
# 1 は ADP 助詞-係助詞 0 case は
# 2 ペンパイナッポーアッポーペン NOUN 名詞-普通名詞-一般 7 advmod ペンパイナッポーアッポーペン
# 3 と ADP 助詞-格助詞 2 case と
# 4 恋 NOUN 名詞-普通名詞-サ変可能 5 compound 恋
# 5 ダンス NOUN 名詞-普通名詞-サ変可能 7 obj ダンス
# 6 を ADP 助詞-格助詞 5 case を
# 7 踊っ VERB 動詞-一般 7 ROOT 踊っ
# 8 た AUX 助動詞 7 aux た
# 9 。 PUNCT 補助記号-句点 7 punct .

# %% [markdown]
# # 入力ファイルに対して形態素解析を行い、ファイルに結果を書き込む

# %%
#文字列の正規化の定義
#表記揺れを減らします。今回はneologdの正規化処理を一部改変したものを利用します。 処理の詳細はリンク先を参照してください。
# https://github.com/neologd/mecab-ipadic-neologd/wiki/Regexp.ja から引用・一部改変
from __future__ import unicode_literals
import re
import unicodedata

def unicode_normalize(cls, s):
    pt = re.compile('([{}]+)'.format(cls))

    def norm(c):
        return unicodedata.normalize('NFKC', c) if pt.match(c) else c

    s = ''.join(norm(x) for x in re.split(pt, s))
    s = re.sub('－', '-', s)
    return s

def remove_extra_spaces(s):
    s = re.sub('[ 　]+', ' ', s)
    blocks = ''.join(('\u4E00-\u9FFF',  # CJK UNIFIED IDEOGRAPHS
                      '\u3040-\u309F',  # HIRAGANA
                      '\u30A0-\u30FF',  # KATAKANA
                      '\u3000-\u303F',  # CJK SYMBOLS AND PUNCTUATION
                      '\uFF00-\uFFEF'   # HALFWIDTH AND FULLWIDTH FORMS
                      ))
    basic_latin = '\u0000-\u007F'

    def remove_space_between(cls1, cls2, s):
        p = re.compile('([{}]) ([{}])'.format(cls1, cls2))
        while p.search(s):
            s = p.sub(r'\1\2', s)
        return s

    s = remove_space_between(blocks, blocks, s)
    s = remove_space_between(blocks, basic_latin, s)
    s = remove_space_between(basic_latin, blocks, s)
    return s

def normalize_neologd(s):
    s = s.strip()
    s = unicode_normalize('０-９Ａ-Ｚａ-ｚ｡-ﾟ', s)

    def maketrans(f, t):
        return {ord(x): ord(y) for x, y in zip(f, t)}

    s = re.sub('[˗֊‐‑‒–⁃⁻₋−]+', '-', s)  # normalize hyphens
    s = re.sub('[﹣－ｰ—―─━ー]+', 'ー', s)  # normalize choonpus
    s = re.sub('[~∼∾〜〰～]+', '〜', s)  # normalize tildes (modified by Isao Sonobe)
    s = s.translate(
        maketrans('!"#$%&\'()*+,-./:;<=>?@[¥]^_`{|}~｡､･｢｣',
              '！”＃＄％＆’（）＊＋，－．／：；＜＝＞？＠［￥］＾＿｀｛｜｝〜。、・「」'))

    s = remove_extra_spaces(s)
    s = unicode_normalize('！”＃＄％＆’（）＊＋，－．／：；＜＞？＠［￥］＾＿｀｛｜｝〜', s)  # keep ＝,・,「,」
    s = re.sub('[’]', '\'', s)
    s = re.sub('[”]', '"', s)
    return s

# %%
def shape_word_by_type(string, type):

    #名詞-普通名詞-一般
    stop_words_name_normal_ge = ['シャツ']

    #名詞-普通名詞-サ変可能
    stop_words_name_normal_sa = ['使用']

    #名詞-固有名詞-人名-一般、名詞-固有名詞-地名-一般
    stop_words_uniq_human = ['']

    #名詞-普通名詞-形状詞可能
    stop_words_name_form = ['詳細']

    #形状詞-一般
    stop_words_form_ge = ['']

    #副詞
    stop_words_sub = ['']

    #ここでストップワードを登録
    stop_words_add = ['']

    #ストップワードを結合
    stop_words_all = stop_words_name_normal_sa + stop_words_name_normal_ge + stop_words_uniq_human + stop_words_name_form + stop_words_form_ge + stop_words_sub + stop_words_file + stop_words_add

    #ストップワードから不要なワードを削除
    stop_words_all.remove('')

    if string in stop_words_all:
      return False
    
    #分類判定
    if type in [
        '名詞-普通名詞-一般', 
        '名詞-普通名詞-サ変可能', 
        '名詞-固有名詞-人名-一般', 
        '名詞-固有名詞-地名-一般', 
        '名詞-普通名詞-形状詞可能', 
        '形状詞-一般', 
        '副詞'
      ]:
      return True
    else:
      return False

def remove_brackets(text):
    text = re.sub(r"(^【[^】]*】)|(【[^】]*】$)", "", text)
    return text

def normalize_text(text):
    #assert "\n" not in text and "\r" not in text
    text = text.replace("\t", " ")
    text = text.strip()
    text = normalize_neologd(text)
    text = text.lower()
    return text

def read_id_sentence_line(line):
    line = normalize_text(remove_brackets(line))
    row = line.split(',')
    n = row[0]
    id = row[1]
    name = row[2]
    sentence = row[3]
    return n, id, name, sentence

def morphological_analize(input_file_path, output_file_path, dt):

  with open(input_file_path) as f:
    toks = []
    for index, line in enumerate(f):

      print("【", index, "】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー")

      #CSVを分解
      n, id, name, sentence = read_id_sentence_line(line)
      
      #Sample tasting
      #sentence = "暑さをクールダウンさせる加工素材を使用した、ビズシーズンにおすすめのスタンダードワイシャツ"
      
      #形態素解析
      doc = nlp(sentence)
      
      #解析結果箱を初期化
      arr_tok_text = []
      arr_tok_tag_ = []
      str_tok_texts = ''
      str_tok_tags = ''

      #形態素解析結果を配列化
      for tok in doc:
          #print(
          #    tok.text,  # 逐語的なテキストコンテンツ
          #    tok.tag_,  # きめの細かい品詞)
          if shape_word_by_type(tok.text, tok.tag_):
            arr_tok_text.append(tok.text)
            arr_tok_tag_.append(tok.tag_)
          
      #解析結果配列をカンマでつないで文字列化
      str_tok_texts = ','.join(arr_tok_text)
      str_tok_tags = ','.join(arr_tok_tag_)

      #０行目はヘッダー
      if index == 0:
        mr = 'cdt|client_id|item_id|name|tokenized|classification|description_summary'

      #入力値と結果値をそれぞれパイプでつないで文字列化
      if index != 0:
        mr = dt + '|' + clientId + '|' + id + '|' + name + '|' + str_tok_texts.replace('\n', '') + '|' + str_tok_tags.replace('\n', '') + '|' + sentence

      #格納する
      toks.append(mr)
      print(mr)

  with open(output_file_path, mode='w') as f:
    for index, s in enumerate(toks):
      #print(s)
      f.write(s+'\n')

# %% [markdown]
# ## 解析を実行
#
# *   Timestampを設定
# *   入力ファイル名と出力先指定を
# *   inference_summaryを実行(ファイルごとにループ上でCall)

# %%
#Timestamp
from datetime import datetime
dt = datetime.now() # Getting the current date and time
ts = datetime.timestamp(dt) # getting the timestamp
print("Date and time is:", dt)
#timestamp to string
sｄｔ = dt.strftime("%Y-%m-%d %H:%M:%S")
sdt = sdt.replace(' ', '_')

#形態素解析
#input_fld = fldContentDriveMyDriveColabNotebooksDataInput
input_fld = fldContentDriveMyDriveColabNotebooksDataOutput
output_fld = fldContentDriveMyDriveColabNotebooksDataOutput

for f in file_names:
  input_file_path = input_fld + f
  output_file_path = output_fld + "tok_" + f
  morphological_analize(input_file_path, output_file_path, sdt)
# Out:
# Date and time is: 2023-05-11 11:26:17.516483
# 【 0 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# cdt|client_id|item_id|name|tokenized|classification|description_summary
# 【 1 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|112049110001|ジュエリークリーナーセット|大切,ジュエリー,手入れ|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能|大切なジュエリーのお手入れにご使用下さい
# 【 2 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152144050001|シルバーイヤーカフ/片耳用|手軽,イヤー,ジュエリー,earjoy|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|手軽に楽しめるイヤージュエリー〈earjoy〉
# 【 3 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152144
|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|可憐な胸元を演出するキュービックジルコニアネックレス
# 【 132 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121002|シルバーネックレス|女性,魅力,モチーフ,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|女性の魅力を引き出す月モチーフネックレス
# 【 133 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121005|シルバーネックレス|輝き,ストーン,煌めき,大人,華やか,プラス|名詞-普通名詞-一般,名詞-固有名詞-人名-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-サ変可能|月の輝きとストーンの煌めきで、大人の華やかさをプラス
# 【 134 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121006|シルバーネックレス|軽やか,フラワー,モチーフ,上品,印象|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般|軽やかなフラワーモチーフが上品な印象に
# 【 135 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121007|シルバーネックレス|幸福,馬蹄,モチーフ,ネックレス|名詞-普通名詞-形状詞可能,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|幸福を呼ぶ馬蹄モチーフのネックレス
# 【 136 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121008|シルバーネックレス|幸福,馬蹄,モチーフ,ネックレス|名詞-普通名詞-形状詞可能,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|幸福を呼ぶ馬蹄モチーフのネックレス
# 【 137 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914131005|シルバーブレスレット|キュート,輝き,キュービック,ジルコニア,ブレスレット|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|キュートな輝きを放つキュービックジルコニアのブレスレット
# 【 138 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914131006|シルバーブレスレット|キュート,キュービック,ジルコニア,ブレスレット|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|キュートなキュービックジルコニアのブレスレット
# 【 139 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251011|シルバーカフリング|カーネリアン,ハート,おひつじ座,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|「カーネリアン」を添えたハート型のおひつじ座カフリング
# 【 140 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251012|シルバーカフリング|星座,カフリング,守護,身|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能,名詞-普通名詞-一般|星座石のカフリングで、守護石として身に着けていただけます
# 【 141 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251013|シルバーカフリング|ふたご座,星座,アゲート,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-固有名詞-人名-一般,名詞-普通名詞-一般|ふたご座の星座石「アゲート」を添えたカフリング
# 【 142 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251014|シルバーカフリング|かに座,星座,ラブラドライト,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|かに座の星座石「ラブラドライト」を添えたカフリング
# 【 143 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251015|シルバーカフリング|しし座,星座,ストーン,パーソナルカフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|しし座の星座にストーンを添えたパーソナルカフリング
# 【 144 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251016|シルバーカフリング|おとめ座,星座,プレー,ナイト,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能,名詞-普通名詞-一般,名詞-普通名詞-一般|おとめ座の星座石「プレーナイト」を添えたカフリング
# 【 145 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251017|シルバーカフリング|星座,カフリング,お守り,身|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能,名詞-普通名詞-一般|星座石のカフリングで、お守りのように身に着けていただけます
# 【 146 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251018|シルバーカフリング|星座,トパーズ,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|さそり座の星座石「トパーズ」を添えたカフリング
# 【 147 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251019|シルバーカフリング|いて座,星座,グリーン,アメシスト,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|いて座の星座石「グリーンアメシスト」を添えたカフリング
# 【 148 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251020|シルバーカフリング|やぎ座,星座,カルセドニー,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-固有名詞-人名-一般,名詞-普通名詞-一般|やぎ座の星座石「カルセドニー」を添えたカフリング
# 【 149 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251021|シルバーカフリング|星座,クォーツ,星座,身|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|星座石のクォーツを添えて、星座石を身に着ける
# 【 150 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152014251022|シルバーカフリング|うお座,星座,ブルー,ムーン,カフリング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-形状詞可能,名詞-普通名詞-一般,名詞-普通名詞-一般|うお座の星座石「ブルームーン」を添えたカフリング
# 【 151 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152034121002|シルバーネックレス|輝き,お守り,身|名詞-普通名詞-一般,名詞-普通名詞-サ変可能,名詞-普通名詞-一般|月の輝く輝きをお守りのように身に着けて
# 【 152 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152034121003|シルバーネックレス|キュービック,ジルコニア,モチーフ,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|キュービックジルコニアがきらめく月モチーフネックレス
# 【 153 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152034121005|シルバーネックレス|幸福,馬蹄,モチーフ,ネックレス|名詞-普通名詞-形状詞可能,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|幸福を呼ぶ馬蹄モチーフネックレス
# 【 154 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|152034121014|シルバーネックレス|キュービック,ジルコニア,可憐,しずく,モチーフ,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|キュービックジルコニ
】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151714541007|シルバーピンキーリング|華奢,可憐,手元,演出,字,ライン,ピンキー,リング|形状詞-一般,形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|華奢で可憐な手元を演出するv字ラインピンキーリング
# 【 200 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151734141001|シルバーリング|指,上品,プラス|名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-サ変可能|指を美しく見せて、上品さをプラス
# 【 201 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151734141005|シルバーリング|キュービック,ジルコニア,女性,プラス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能|キュービックジルコニアが女性らしさをプラス
# 【 202 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151736153013|k10イエローゴールドピアス|きらめき,大人,女性,華やか|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般|月のきらめきが大人の女性を華やかに彩る
# 【 203 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151744121023|シルバーネックレス|輝き,キュービック,ジルコニア,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|“眩い輝き"が眩しいキュービックジルコニアのネックレス
# 【 204 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151744121027|シルバーネックレス|輝き,女性,キュービック,ジルコニア,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|“眩い輝き"が女性らしさを引き立てる、キュービックジルコニアのネックレス
# 【 205 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151746153104|k10ピンクゴールドピアス|キュービック,ジルコニア,キュート,ピアス|名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般|キュービックジルコニアが揺れるキュートなピアス
# 【 206 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151824121026|シルバーネックレス|キュービック,ジルコニア,ハート,モチーフ,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|キュービックジルコニアがきらめく、ハートモチーフのネックレス
# 【 207 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151824141007|シルバーリング|可憐,輝き,キュービック,ジルコニア,リング|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|可憐な輝きを放つキュービックジルコニアのリング
# 【 208 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151824141008|シルバーリング|キュービック,ジルコニア,煌めき,上品,輝き,プラス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能|キュービックジルコニアの煌めきで、上品な輝きをプラス
# 【 209 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151836153111|k10ピンクゴールドピアス|しずく,輝き,ピアス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|しずくが滴るような瑞々しい輝きのピアス
# 【 210 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151844121010|シルバーネックレス|キュート,キュービック,ジルコニア|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|キュートなキュービックジルコニアが優しく優しく輝きます
# 【 211 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151844121013|シルバーネックレス|キュート,輝き,キュービック,ジルコニア,ネックレス|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|キュートな輝きを放つキュービックジルコニアのネックレス
# 【 212 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151844121016|シルバーネックレス|可憐,印象,軽やか,フラワー,モチーフ,ネックレス|形状詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|可憐な印象の軽やかなフラワーモチーフネックレス
# 【 213 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151844121017|シルバーネックレス|キュービック,ジルコニア,輝き,上品,プラス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-サ変可能|キュービックジルコニアのきらめく輝きで、上品さをプラス
# 【 214 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151844141004|シルバーリング|キュービック,ジルコニア,大人,華やか,プラス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-サ変可能|キュービックジルコニアで大人の華やかさをプラス
# 【 215 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151844541007|シルバーピンキーリング|やわらか,字,ライン,女性,ピンキー,リング|形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|やわらかなv字ラインが女性らしさを引き立てるピンキーリング
# 【 216 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121003|シルバーネックレス|キュービック,ジルコニア,しずく,モチーフ,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|「キュービックジルコニア」のしずくモチーフネックレス
# 【 217 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121013|シルバーネックレス|ハート,可憐,ハート,ネックレス|名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|ハートが煌く、可憐なオープンハートのネックレス
# 【 218 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151914121016|シルバーネックレス|しずく,モチーフ,ネックレス,大人,華やか,プラス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-サ変可能|しずくモチーフのネックレスで、大人の華やかさをプラス
# 【 219 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151916153007|k10イエローゴールドピアス|パール,ピアス|名詞-普通名詞-一般,名詞-普通名詞-一般|揺れるたびに煌めき輝く、パールのピアス
# 【 220 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151924141002|シルバーリング|ピンク,ゴールドカラー,輝き,大人,女性,魅了|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能|ピンクゴールドカラーの輝きが大人の女性を魅了!
# 【 221 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|151924141003|シルバーリング|爽やか,ブルー,ストーン,華やか,デザイン,ネックレス|形状詞-一般,名詞-普通名詞-形状詞可能,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-サ変可能,名詞-普通名詞-一般|爽やかなブルーのストーンがきらめく、華やかなデザインのネックレス
# 【 222 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|
】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|112113125011|プラチナネックレス|ダイヤモンド,輝き,ダイヤモンド,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|ダイヤモンドの輝きを際立たせる、ダイヤモンドネックレス
# 【 619 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111743125022|プラチナネックレス|ダイヤモンド,輝き,存分,エレガント,胸元|名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-形状詞可能,名詞-普通名詞-一般|ダイヤモンドの輝きを存分に活かしたエレガントな胸元
# 【 620 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111943145003|プラチナリング|ダイヤモンド,光,ハーフ,エタニティ,リング|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|輝くダイヤモンドが眩い光を放つハーフエタニティリング
# 【 621 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111823125008|プラチナダイヤモンドネックレス0.3ct|気品,プラチナ,粒,ダイヤモンド,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|気品を添える、プラチナの一粒ダイヤモンドネックレス
# 【 622 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111823155005|プラチナピアス|気品,プラチナ,粒,ダイヤモンド,ピアス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|気品を添える、プラチナの一粒ダイヤモンドピアス
# 【 623 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111823145005|プラチナリング|ダイヤモンド,煌めき,エレガント,手元,演出|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-形状詞可能,名詞-普通名詞-一般,名詞-普通名詞-サ変可能|ダイヤモンドの煌めきでエレガントな手元を演出
# 【 624 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111823125011|プラチナネックレス|ダイヤモンド,輝き,最大限,優美,ジュエリー|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般|ダイヤモンドの輝きを最大限に引き出す、優美なジュエリー
# 【 625 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111823125009|プラチナダイヤモンドネックレス0.4ct|輝き,ダイヤモンド,輝き,粒,ダイヤモンド,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|輝きを放つダイヤモンドが眩しい輝きを放つ、1粒ダイヤモンドネックレス
# 【 626 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|111823145006|プラチナリング|ダイヤモンド,輝き,優美,手元,演出|名詞-普通名詞-一般,名詞-普通名詞-一般,形状詞-一般,名詞-普通名詞-一般,名詞-普通名詞-サ変可能|ダイヤモンドの輝きが優美な手元を演出
# 【 627 】ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
# 2023-05-11_11:26:17|fdc|112133125009|プラチナダイヤモンドネックレス0.5ct|輝き,ダイヤモンド,輝き,粒,ダイヤモンド,ネックレス|名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般,名詞-普通名詞-一般|輝きを放つダイヤモンドが眩しい輝きを放つ、1粒ダイヤモンドネックレス

# %% [markdown]
# 出力したCSVをDataframe化し、BigQueryへ連携

# %%
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'bwing-230309'
location = 'asia-northeast1'
table = 'attachment_' + clientId + '.import_colab2bq_tokenized_description'

client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
from pandas.core.indexing import IndexingError
import csv, os
import pandas as pd
import numpy as np

output_fld = fldContentDriveMyDriveColabNotebooksDataOutput

df = pd.DataFrame()
i=0
for f in file_names:
  i += 1
  file_path = output_fld + "tok_" + f
  print("file name:" + file_path)

  #CSVファイルからdfへ変換
  #df = df.append(pd.read_csv(file_path, sep='|'))
  df = pd.read_csv(file_path, sep='|')

  #読み込んだデータの表示
  df.head()

  #bigqueryのテーブルを
  if i==1:
    df.to_gbq(table, project_id=project, if_exists="replace")  
  else:
    df.to_gbq(table, project_id=project, if_exists="append")
# Out:
# file name:/content/drive/MyDrive/ColabNotebooks/data/output/fdc_20230501/tok_inferenced_t5_t5_1-1000.csv
# 100%|██████████| 1/1 [00:00<00:00, 1800.13it/s]
# file name:/content/drive/MyDrive/ColabNotebooks/data/output/fdc_20230501/tok_inferenced_t5_t5_1001-2000.csv
# 100%|██████████| 1/1 [00:00<00:00, 7724.32it/s]
